# %%
from Scweet.scweet import scrape
from Scweet.user import get_user_information, get_users_following, get_users_followers
from Scweet.scweet import scrape
from Scweet.utils import init_driver, log_in
from time import sleep
import pandas as pd
import time

# %%
while True:
    data = scrape(
        from_account="@CNN",
        until="2023-09-26",
        since="2023-09-24",
        interval=1,
        headless=True,
        display_type="Top",
        save_images=False,
        proxy=None,
        save_dir="outputs",
        resume=False,
        filter_replies=True,
        proximity=False,
    )
    sleep(2)
# Out:
# Scraping on headless mode.
# looking for tweets between 2023-09-24 and 2023-09-25 ...
#  path : https://twitter.com/search?q=(from%3A@CNN)%20until%3A2023-09-25%20since%3A2023-09-24%20%20-filter%3Areplies&src=typed_query
# Tweet made at: 2023-09-24T10:29:04.000Z is found.
# Tweet made at: 2023-09-24T00:15:17.000Z is found.
# Tweet made at: 2023-09-24T11:00:07.000Z is found.
# Tweet made at: 2023-09-24T17:59:04.000Z is found.
# scroll  1
# Tweet made at: 2023-09-24T07:00:02.000Z is found.
# Tweet made at: 2023-09-24T19:59:05.000Z is found.
# Tweet made at: 2023-09-24T11:29:03.000Z is found.
# Tweet made at: 2023-09-24T13:46:01.000Z is found.
# scroll  2
# Tweet made at: 2023-09-24T02:20:07.000Z is found.
# Tweet made at: 2023-09-24T01:20:07.000Z is found.
# Tweet made at: 2023-09-24T23:00:11.000Z is found.
# Tweet made at: 2023-09-24T16:33:20.000Z is found.
# Tweet made at: 2023-09-24T17:15:03.000Z is found.
# scroll  3
# Tweet made at: 2023-09-24T05:30:04.000Z is found.
# Tweet made at: 2023-09-24T00:00:10.000Z is found.
# Tweet made at: 2023-09-24T10:00:17.000Z is found.
# Tweet made at: 2023-09-24T14:20:02.000Z is found.
# Tweet made at: 2023-09-24T21:00:04.000Z is found.
# Tweet made at: 2023-09-24T14:30:11.000Z is found.
# scroll  4
# scroll  5
# scroll  6
# looking for tweets between 2023-09-25 and 2023-09-26 ...
#  path : https://twitter.com/search?q=(from%3A@CNN)%20until%3A2023-09-26%20since%3A2023-09-25%20%20-filter%3Areplies&src=typed_query
# Tweet made at: 2023-09-25T01:00:07.000Z is found.
# Tweet made at: 2023-09-25T04:00:06.000Z is found.
# Tweet made at: 2023-09-25T02:30:08.000Z is found.
# Tweet made at: 2023-09-25T09:22:06.000Z is found.
# scroll  1
# Tweet made at: 2023-09-25T04:30:04.000Z is found.
# Tweet made at: 2023-09-25T03:30:09.000Z is found.
# Tweet made at: 2023-09-25T02:06:14.000Z is found.
# Tweet made at: 2023-09-25T05:30:09.000Z is found.
# Tweet made at: 2023-09-25T06:30:05.000Z is found.
# Tweet made at: 2023-09-25T02:00:07.000Z is found.
# Tweet made at: 2023-09-25T01:30:05.000Z is found.
# Tweet made at: 2023-09-25T05:45:06.000Z is found.
# Tweet made at: 2023-09-25T03:00:08.000Z is found.
# Tweet made at: 2023-09-25T06:15:05.000Z is found.
# scroll  2
# scroll  3
# scroll  4
# Scraping on headless mode.
# looking for tweets between 2023-09-24 and 2023-09-25 ...
#  path : https://twitter.com/search?q=(from%3A@CNN)%20until%3A2023-09-25%20since%3A2023-09-24%20%20-filter%3Areplies&src=typed_query
# Tweet made at: 
a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>         headless=True,
#       <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>         display_type="Top",
#       <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>         save_images=False,
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a>         proxy=None,
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>         save_dir="outputs",
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>         resume=False,
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a>         filter_replies=True,
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a>         proximity=False,
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/jirateep_t/Tweets-sraping/scraping.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a>     sleep(2)
#
# File c:\Users\jirateep_t\Tweets-sraping\Scweet\scweet.py:225, in scrape(since, until, words, to_account, from_account, mention_account, interval, lang, headless, limit, display_type, resume, proxy, hashtag, show_images, save_images, save_dir, filter_replies, proximity, geocode, minreplies, minlikes, minretweets, env)
#     214 sleep(random.uniform(0.5, 1.5))
#     215 # start scrolling and get tweets
#     216 (
#     217     driver,
#     218     data,
#     219     writer,
#     220     tweet_ids,
#     221     scrolling,
#     222     tweet_parsed,
#     223     scroll,
#     224     last_position,
# --> 225 ) = keep_scroling(
#     226     driver,
#     227     data,
#     228     writer,
#     229     tweet_ids,
#     230     scrolling,
#     231     tweet_parsed,
#     232     limit,
#     233     scroll,
#     234     last_position,
#     235 )
#     237 # keep updating <start date> and <end date> for every search
#     238 if type(since) == str:
#
# File c:\Users\jirateep_t\Tweets-sraping\Scweet\utils.py:285, in keep_scroling(driver, data, writer, tweet_ids, scrolling, tweet_parsed, limit, scroll, last_position, save_images)
#     283 page_cards = driver.find_elements(by=By.XPATH, value='//article[@data-testid="tweet"]')  # changed div by article
#     284 for card in page_cards:
# --> 285     tweet = get_data(card, save_images, save_images_dir)
#     286     if tweet:
#     287         # check if the tweet is unique
#     288         tweet_id = ''.join(tweet[:-2])
#
# File c:\Users\jirateep_t\Tweets-sraping\Scweet\utils.py:102, in get_data(card, save_images, save_dir)
#     100 for tag in emoji_tags:
#     101     try:
# --> 102         filename = tag.get_attribute('src')
#     103         emoji = chr(int(re.search(r'svg\/([a-z0-9]+)\.svg', filename).group(1), base=16))
#     104     except AttributeError:
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:173, in WebElement.get_attribute(self, name)
#     171 if getAttribute_js is None:
#     172     _load_js()
# --> 173 attribute_value = self.parent.execute_script(
#     174     "return (%s).apply(null, arguments);" % getAttribute_js,
#     175     self, name)
#     176 return attribute_value
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:884, in WebDriver.execute_script(self, script, *args)
#     881 converted_args = list(args)
#     882 command = Command.W3C_EXECUTE_SCRIPT
# --> 884 return self.execute(command, {
#     885     'script': script,
#     886     'args': converted_args})['value']
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     425         params['sessionId'] = self.session_id
#     427 params = self._wrap_value(params)
# --> 428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
#     430     self.error_handler.check_response(response)
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:347, in RemoteConnection.execute(self, command, params)
#     345 data = utils.dump_json(params)
#     346 url = f"{self._url}{path}"
# --> 347 return self._request(command_info[0], url, body=data)
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:369, in RemoteConnection._request(self, method, url, body)
#     366     body = None
#     368 if self.keep_alive:
# --> 369     response = self._conn.request(method, url, body=body, headers=headers)
#     370     statuscode = response.status
#     371 else:
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\jirateep_t\AppData\Local\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
