# %%
import time
import pandas as pd
from datetime import datetime

# %%
iter = 0
while True:
    iter += 1
    try:
        # Read the CSV file into a DataFrame
        df = pd.read_csv(
            r"C:\Users\jirateep_t\Tweets-sraping\outputs\@CNN_2023-09-24_2023-09-26.csv"
        )

        # Process the data as needed
        # For example, you can print the first few rows:
        # display(df.head())
        print(f"({iter})", datetime.now(), df.shape)

        # Add a delay before the next iteration
        time.sleep(10)  # Adjust the delay time as needed
    except KeyboardInterrupt:
        # If you want to stop the loop manually (e.g., by pressing Ctrl+C)
        break
    except FileNotFoundError:
        # Handle the case where the file is not found
        print(f"File {file_path} not found. Retrying in 10 seconds...")
        time.sleep(10)
    except Exception as e:
        # Handle other exceptions gracefully
        print(f"An error occurred: {e}")
# Out:
# (1) 2023-09-25 17:21:06.603242 (40, 11)
# (2) 2023-09-25 17:21:16.606566 (40, 11)
# (3) 2023-09-25 17:21:26.614613 (40, 11)
# (4) 2023-09-25 17:21:36.617809 (40, 11)
# (5) 2023-09-25 17:21:46.624166 (40, 11)
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# An error occurred: No columns to parse from file
# ...
